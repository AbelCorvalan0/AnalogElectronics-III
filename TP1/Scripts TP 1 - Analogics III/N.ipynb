# %%
import sympy as sym
import numpy as np

L, mu, N, S, l= sym.symbols('L, mu, N, S, l')

mu_0= 4*np.pi*(10)**(-7)
mu= mu_0*1

D= 0.0186

S= 2*np.pi*(D/2)**2

#Despejo N
e= (mu*((N)**2)*S)/(l)
equ= sym.solve(sym.Eq(L, e), N)
sym.pprint(equ)

import matplotlib.pyplot as plt

def f(L, l, S):
    return (892.062*np.sqrt((L*l)/S))

xlist= np.linspace(300e-9, 1000e-9, num= 1000)
#zlist= np.linspace(0.032, 0.05, num= 1000)

#ylist= f(xlist, 0.04, 0.002)
ylist= f(xlist, 0.045, 0.0005)

plt.figure(num= 0, dpi=1200)
plt.plot(xlist, ylist)
plt.xlabel("L[nHy]")
plt.ylabel("N[cant espiras]")
plt.grid()
# Out:
# ⎡                    _____                     _____⎤
# ⎣-38266.8034095256⋅╲╱ L⋅l , 38266.8034095256⋅╲╱ L⋅l ⎦
